# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\aayush srivastava\anaconda3\lib\site-packages (0.9.2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from librosa) (2.1.9)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from librosa) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from librosa) (21.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from librosa) (1.0.2)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: joblib>=0.14 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: pooch>=1.0 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: numba>=0.45.1 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from librosa) (0.55.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from librosa) (1.7.3)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\aayush srivastava\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (61.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (3.0.4)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.9)
# Requirement already satisfied: six>=1.3 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from resampy>=0.2.2->librosa) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\aayush srivastava\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\aayush srivastava\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)

# %%
pip install keras==2.9.0
# Out:
# Requirement already satisfied: keras==2.9.0 in c:\users\aayush srivastava\anaconda3\lib\site-packages (2.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename='UrbanSound8K/dog_bark.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
# !dir
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is B417-ECE0
#
#  Directory of C:\Users\Aayush Srivastava\NTCC
#
# 07/20/2022  02:28 AM    <DIR>          .
# 07/20/2022  02:28 AM    <DIR>          ..
# 07/13/2022  03:01 AM    <DIR>          .ipynb_checkpoints
# 07/20/2022  02:28 AM           153,753 Audio Classification Data Processing & Model Creation.ipynb
# 07/20/2022  01:56 AM         1,983,239 Audio Classification EDA.ipynb
# 07/05/2022  06:44 PM    <DIR>          saved_models
# 07/07/2022  07:49 PM    <DIR>          UrbanSound8K
#                2 File(s)      2,136,992 bytes
#                5 Dir(s)  88,107,720,704 bytes free

# %%
### Dog Sound
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
### Sound
filename='UrbanSound8K/100263-2-0-3.wav'
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[ 194,  100],
#        [ 179,  113],
#        [ 160,  124],
#        ...,
#        [-143,  -87],
#        [-134,  -91],
#        [-110,  -98]], dtype=int16)

# %%
data
# Out:
# array([ 0.00330576,  0.00468387,  0.00360455, ..., -0.0037562 ,
#        -0.00348641, -0.00356705], dtype=float32)

# %%
import pandas as pd

metadata=pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')
metadata.head(10)
# Out:
#       slice_file_name    fsID      start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032   0.000000   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263  58.500000  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263  60.500000  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263  63.000000  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263  68.500000  72.500000         1     5        2
# 5  100263-2-0-143.wav  100263  71.500000  75.500000         1     5        2
# 6  100263-2-0-161.wav  100263  80.500000  84.500000         1     5        2
# 7    100263-2-0-3.wav  100263   1.500000   5.500000         1     5        2
# 8   100263-2-0-36.wav  100263  18.000000  22.000000         1     5        2
# 9    100648-1-0-0.wav  100648   4.823402   5.471927         2    10        1
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing
# 5  children_playing
# 6  children_playing
# 7  children_playing
# 8  children_playing
# 9          car_horn

# %%
### Check whether the dataset is imbalanced
metadata['class'].value_counts()
# Out:
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64
